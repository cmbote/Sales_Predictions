# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
filename = '/content/drive/MyDrive/Coding Dojo Data Science/PandasForDataManipulation/sales_predictions.csv'
df = pd.read_csv(filename)
df.head(20)
# Out:
#    Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0            FDA15        9.300  ...  Supermarket Type1          3735.1380
# 1            DRC01        5.920  ...  Supermarket Type2           443.4228
# 2            FDN15       17.500  ...  Supermarket Type1          2097.2700
# 3            FDX07       19.200  ...      Grocery Store           732.3800
# 4            NCD19        8.930  ...  Supermarket Type1           994.7052
# 5            FDP36       10.395  ...  Supermarket Type2           556.6088
# 6            FDO10       13.650  ...  Supermarket Type1           343.5528
# 7            FDP10          NaN  ...  Supermarket Type3          4022.7636
# 8            FDH17       16.200  ...  Supermarket Type1          1076.5986
# 9            FDU28       19.200  ...  Supermarket Type1          4710.5350
# 10           FDY07       11.800  ...  Supermarket Type1          1516.0266
# ...

# %%
# Renaming Columns
df.columns = ['Product ID', 'Weight','Low Fat or Regular','Visibility','Product Category','Product List Price','Store ID','Year Opened','Size of Store','Area of Store','Grocery Store or Supermarket','Item_Outlet_Sales']
df.head(20)
# Out:
#    Product ID  Weight  ... Grocery Store or Supermarket  Item_Outlet_Sales
# 0       FDA15   9.300  ...            Supermarket Type1          3735.1380
# 1       DRC01   5.920  ...            Supermarket Type2           443.4228
# 2       FDN15  17.500  ...            Supermarket Type1          2097.2700
# 3       FDX07  19.200  ...                Grocery Store           732.3800
# 4       NCD19   8.930  ...            Supermarket Type1           994.7052
# 5       FDP36  10.395  ...            Supermarket Type2           556.6088
# 6       FDO10  13.650  ...            Supermarket Type1           343.5528
# 7       FDP10     NaN  ...            Supermarket Type3          4022.7636
# 8       FDH17  16.200  ...            Supermarket Type1          1076.5986
# 9       FDU28  19.200  ...            Supermarket Type1          4710.5350
# 10      FDY07  11.800  ...            Supermarket Type1          1516.0266
# ...

# %%
df.dtypes
# Out:
# Product ID                       object
# Weight                          float64
# Low Fat or Regular               object
# Visibility                      float64
# Product Category                 object
# Product List Price              float64
# Store ID                         object
# Year Opened                       int64
# Size of Store                    object
# Area of Store                    object
# Grocery Store or Supermarket     object
# Item_Outlet_Sales               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Product ID                         0
# Weight                          1463
# Low Fat or Regular                 0
# Visibility                         0
# Product Category                   0
# Product List Price                 0
# Store ID                           0
# Year Opened                        0
# Size of Store                   2410
# Area of Store                      0
# Grocery Store or Supermarket       0
# Item_Outlet_Sales                  0
# dtype: int64

# %%
# Creating column "Size of Store 2" that displays "Size of Store" text respones as numbers
df.loc[df['Size of Store'] == 'High', 'Size of Store 2'] = 1
df.loc[df['Size of Store'] == 'Medium', 'Size of Store 2'] = 2
df.loc[df['Size of Store'] == 'Small', 'Size of Store 2'] = 3
df
# Out:
#      Product ID  Weight  ... Item_Outlet_Sales  Size of Store 2
# 0         FDA15   9.300  ...         3735.1380              2.0
# 1         DRC01   5.920  ...          443.4228              2.0
# 2         FDN15  17.500  ...         2097.2700              2.0
# 3         FDX07  19.200  ...          732.3800              NaN
# 4         NCD19   8.930  ...          994.7052              1.0
# ...         ...     ...  ...               ...              ...
# 8518      FDF22   6.865  ...         2778.3834              1.0
# 8519      FDS36   8.380  ...          549.2850              NaN
# 8520      NCJ29  10.600  ...         1193.1136              3.0
# 8521      FDN46   7.210  ...         1845.5976              2.0
# 8522      DRG01  14.800  ...          765.6700              3.0
#
# [8523 rows x 13 columns]

# %%
# Dropping "Size of Store" with text responses for now
df1 = df.drop(['Size of Store'], axis=1)
df1.head()
# Out:
#   Product ID  Weight  ... Item_Outlet_Sales  Size of Store 2
# 0      FDA15    9.30  ...         3735.1380              2.0
# 1      DRC01    5.92  ...          443.4228              2.0
# 2      FDN15   17.50  ...         2097.2700              2.0
# 3      FDX07   19.20  ...          732.3800              NaN
# 4      NCD19    8.93  ...          994.7052              1.0
#
# [5 rows x 12 columns]

# %%
df1.isnull().sum()
# Out:
# Product ID                         0
# Weight                          1463
# Low Fat or Regular                 0
# Visibility                         0
# Product Category                   0
# Product List Price                 0
# Store ID                           0
# Year Opened                        0
# Area of Store                      0
# Grocery Store or Supermarket       0
# Item_Outlet_Sales                  0
# Size of Store 2                 2410
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = 'most_frequent')
df1 = imputer.fit_transform(df1)

# %%
df1
# Out:
# array([['FDA15', 9.3, 'Low Fat', ..., 'Supermarket Type1', 3735.138, 2.0],
#        ['DRC01', 5.92, 'Regular', ..., 'Supermarket Type2', 443.4228,
#         2.0],
#        ['FDN15', 17.5, 'Low Fat', ..., 'Supermarket Type1', 2097.27, 2.0],
#        ...,
#        ['NCJ29', 10.6, 'Low Fat', ..., 'Supermarket Type1', 1193.1136,
#         3.0],
#        ['FDN46', 7.21, 'Regular', ..., 'Supermarket Type2', 1845.5976,
#         2.0],
#        ['DRG01', 14.8, 'Low Fat', ..., 'Supermarket Type1', 765.67, 3.0]],
#       dtype=object)

# %%
# Converting array above to dataframe
df1 = pd.DataFrame(df1, columns = ['Product ID', 'Weight','Low Fat or Regular','Visibility','Product Category','Product List Price','Store ID','Year Opened','Area of Store','Grocery Store or Supermarket','Item_Outlet_Sales','Size of Store 2'])

# %%
df1
# Out:
#      Product ID Weight  ... Item_Outlet_Sales Size of Store 2
# 0         FDA15    9.3  ...           3735.14               2
# 1         DRC01   5.92  ...           443.423               2
# 2         FDN15   17.5  ...           2097.27               2
# 3         FDX07   19.2  ...            732.38               2
# 4         NCD19   8.93  ...           994.705               1
# ...         ...    ...  ...               ...             ...
# 8518      FDF22  6.865  ...           2778.38               1
# 8519      FDS36   8.38  ...           549.285               2
# 8520      NCJ29   10.6  ...           1193.11               3
# 8521      FDN46   7.21  ...            1845.6               2
# 8522      DRG01   14.8  ...            765.67               3
#
# [8523 rows x 12 columns]

# %%
df1.isnull().sum()
# Out:
# Product ID                      0
# Weight                          0
# Low Fat or Regular              0
# Visibility                      0
# Product Category                0
# Product List Price              0
# Store ID                        0
# Year Opened                     0
# Area of Store                   0
# Grocery Store or Supermarket    0
# Item_Outlet_Sales               0
# Size of Store 2                 0
# dtype: int64

# %%
# Adding back column "Size of Store" that displays "Size of Store 2" impute calcualtion back as text
df1.loc[df1['Size of Store 2'] == 1, 'Size of Store'] = "High"
df1.loc[df1['Size of Store 2'] == 2, 'Size of Store'] = "Medium"
df1.loc[df1['Size of Store 2'] == 3, 'Size of Store'] = "Low"
df1
# Out:
#      Product ID Weight  ... Size of Store 2 Size of Store
# 0         FDA15    9.3  ...               2        Medium
# 1         DRC01   5.92  ...               2        Medium
# 2         FDN15   17.5  ...               2        Medium
# 3         FDX07   19.2  ...               2        Medium
# 4         NCD19   8.93  ...               1          High
# ...         ...    ...  ...             ...           ...
# 8518      FDF22  6.865  ...               1          High
# 8519      FDS36   8.38  ...               2        Medium
# 8520      NCJ29   10.6  ...               3           Low
# 8521      FDN46   7.21  ...               2        Medium
# 8522      DRG01   14.8  ...               3           Low
#
# [8523 rows x 13 columns]

# %%
df1.isnull().sum()
# Out:
# Product ID                      0
# Weight                          0
# Low Fat or Regular              0
# Visibility                      0
# Product Category                0
# Product List Price              0
# Store ID                        0
# Year Opened                     0
# Area of Store                   0
# Grocery Store or Supermarket    0
# Item_Outlet_Sales               0
# Size of Store 2                 0
# Size of Store                   0
# dtype: int64

# %%
df1['Product Category'].describe()
# Out:
# count                      8523
# unique                       16
# top       Fruits and Vegetables
# freq                       1232
# Name: Product Category, dtype: object

# %%
df1['Product Category'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Product Category, dtype: int64

# %%
df1.groupby(['Grocery Store or Supermarket','Product Category'])[['Product List Price']].count()
# Out:
#                                                Product List Price
# Grocery Store or Supermarket Product Category
# Grocery Store                Baking Goods                      85
#                              Breads                            33
#                              Breakfast                         19
#                              Canned                            73
#                              Dairy                             92
# ...                                                           ...
# Supermarket Type3            Others                            15
#                              Seafood                            7
#                              Snack Foods                      137
#                              Soft Drinks                       45
#                              Starchy Foods                     14
#
# [64 rows x 1 columns]

# %%
df1.groupby('Product Category')['Product List Price'].describe()
# Out:
#                         count  unique       top  freq
# Product Category
# Baking Goods            648.0   602.0  195.8136   3.0
# Breads                  251.0   226.0  260.4594   3.0
# Breakfast               110.0   104.0  128.7994   2.0
# Canned                  649.0   598.0   94.4094   3.0
# Dairy                   682.0   625.0  219.3482   3.0
# Frozen Foods            856.0   780.0   43.3454   3.0
# Fruits and Vegetables  1232.0  1110.0  234.4958   3.0
# Hard Drinks             214.0   206.0  188.1872   3.0
# Health and Hygiene      520.0   475.0  224.4404   3.0
# Household               910.0   846.0  110.4912   3.0
# Meat                    425.0   377.0   37.9532   3.0
# Others                  169.0   160.0  243.0196   2.0
# Seafood                  64.0    61.0   34.2216   2.0
# Snack Foods            1200.0  1079.0  120.8756   4.0
# Soft Drinks             445.0   418.0  172.3106   2.0
# Starchy Foods           148.0   141.0   78.2960   2.0

# %%
df1['Grocery Store or Supermarket'].value_counts(normalize=True)
# Out:
# Supermarket Type1    0.654347
# Grocery Store        0.127068
# Supermarket Type3    0.109703
# Supermarket Type2    0.108882
# Name: Grocery Store or Supermarket, dtype: float64
